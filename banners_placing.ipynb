# %% [markdown]
# In this notebook we perform cluster analysis on Foursquare dataset to find the most optimal locations to place banners of Carnival Cruise Line company. From Foursquare dataset, which is available by this link: https://archive.org/details/201309_foursquare_dataset_umn , we have used checkings.dat. Our aim is 20 closest to Carnival Cruise Line offices high density clusters.

# %%
from sklearn import cluster, model_selection

import numpy as np
import pandas as pd

# %%
data = pd.read_csv('checkins.dat', sep = '|', header = 0, skipinitialspace = True)
data.dropna(inplace = True)  #delete all rows with no latitude and longitude info
data = data.reset_index(drop=True)  #as we have deleted some rows, we should reset indexes in our dataframe
data.head()
# Out:
# C:\ProgramData\Anaconda2\lib\site-packages\IPython\core\interactiveshell.py:2714: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#     id       user_id   venue_id   latitude        longitude       \
# 0  984222     15824.0     5222.0       38.895112      -77.036366
# 1  984234     44652.0     5222.0       33.800745      -84.410520
# 2  984291    105054.0     5222.0       45.523452     -122.676207
# 3  984318   2146539.0     5222.0       40.764462     -111.904565
# 4  984232     93870.0   380645.0       33.448377     -112.074037
#
#       created_at
# 0  2012-04-21 17:43:47
# 1  2012-04-21 17:43:43
# 2  2012-04-21 17:39:22
# 3  2012-04-21 17:35:46
# 4  2012-04-21 17:38:18

# %%
print data.shape
print data.dtypes
# Out:
# (396634, 6)
# id                   object
# user_id             float64
# venue_id            float64
# latitude            float64
# longitude           float64
# created_at           object
# dtype: object

# %% [markdown]
# I have chosen Mean Shift algorithm to solve this problem, because it is a centroid based algorithm and its clustering aims to discover blobs in a smooth density of samples. So, it's perfect to fit our dataset, where we want to discover users accumulations.

# %%
cluster_analyzer = cluster.MeanShift(bandwidth = 0.1)

# %% [markdown]
# To achieve correct answer in the examination system I only have to use first 100000 rows of dataset. Of course, it's possible to perform clustering on whole dataset, but it takes 1 hour vs 2 minutes.
#
# I also dropped out first 3 columns of dataset as non-informative and last one because we need to analyze total visits of current place, not visits at different times.

# %%
data = data[:100000]
data = data.iloc[xrange(0, 100000), [3, 4]]
data.head()
# Out:
#    latitude        longitude
# 0       38.895112      -77.036366
# 1       33.800745      -84.410520
# 2       45.523452     -122.676207
# 3       40.764462     -111.904565
# 4       33.448377     -112.074037

# %%
cluster_analyzer.fit(data)
# Out:
# MeanShift(bandwidth=0.1, bin_seeding=False, cluster_all=True, min_bin_freq=1,
#      n_jobs=None, seeds=None)

# %%
cluster_labels = cluster_analyzer.labels_  #this array contains labels of clusters to which our algorithm took our
                                           #datasets rows

# %% [markdown]
# Now it's time to calculate centres of clusters as optimal loactions to place banners.

# %%
#count how many elements we have in each cluster
numbers_of_el_in_clust = np.zeros(np.max(cluster_labels) + 1)
for i in cluster_labels:
    numbers_of_el_in_clust[i] += 1

centers_of_clusters = []
for i in xrange(0, max(cluster_labels) + 1):
    lat_sum = 0.
    long_sum = 0.
    for index, k in enumerate(cluster_labels):
        if k == i:
            lat_sum += data.iloc[index,0]
            long_sum += data.iloc[index,1]
    centers_of_clusters.append(tuple((lat_sum / numbers_of_el_in_clust[i], long_sum / numbers_of_el_in_clust[i])))

# %% [markdown]
# Define function, which should delete an array of elements from usual Python list by their indexes.

# %%
def multi_delete(list_, args):
    indexes = sorted(args, reverse=True)
    for index in indexes:
        del list_[index]
    return list_

# %% [markdown]
# Clusters, which have less than 16 points aren't interesting for us.

# %%
ind_to_del = []

for i in xrange(0, np.max(cluster_labels)):
    if numbers_of_el_in_clust[i] <= 15:
        ind_to_del.append(i)
        
centers_of_bigger_clusters = multi_delete(centers_of_clusters, ind_to_del)

# %% [markdown]
# I used mapcustomizer to visualize centres of clusters. Here you can see what we got:
#
# https://www.mapcustomizer.com/map/cluster_centres

# %%
for coord in centers_of_bigger_clusters:
    print format(coord[0]) + ', ' + format(coord[1]) + '\n'
# Out:
# 40.7187068678, -73.9920583378
#
# 33.4481210773, -112.073750349
#
# 33.4512308635, -111.917519658
#
# 41.8782437797, -87.6298433623
#
# 37.7186956146, -122.413579805
#
# 38.8865003439, -77.047520192
#
# 33.3570196815, -111.822739909
#
# 33.7670181941, -84.3958447009
#
# 42.3636725818, -71.0786283254
#
# 47.6062447174, -122.332043826
#
# 36.1171880912, -115.170948319
#
# 34.0521041243, -118.243687819
#
# 44.9800773692, -93.2637154264
#
# 30.267183617, -97.7431192813
#
# 40.7426274749, -73.8047918971
#
# 39.7387950389, -104.986707004
#
# 39.9521041075, -75.1634382844
#
# 34.0219947974, -118.458868348
#
# 32.9808933822, -117.078117978
#
# 32.8030205353, -96.7698974349
#
# 37.3361803361, -121.918048608
#
# 28.5379692463, -81.3792742065
#
# 32.7082197123, -117.151373994
#
# 32.2217131518, -110.926535153
#
# 34.1344681763, -118.359115764
#
# 29.7626977547, -95.3823137047
#
# 43.0395059286, -87.9063213048
#
# 33.8312803288, -117.899132299
#
# 37.3961366695, -122.097224695
#
# 25.7900492355, -80.2125575741
#
# 45.5234832146, -122.676280421
#
# 33.5461277671, -112.296685059
#
# 33.669016929, -117.918594613
#
# -6.20874898267, 106.846375904
#
# 27.9494460796, -82.4650736
#
# 34.1563751519, -118.249398167
#
# 39.103591065, -94.5817173536
#
# 35.227263381, -80.8431816171
#
# 43.6529502219, -79.3826088698
#
# 37.8004246475, -122.267560358
#
# 39.996310526, -82.9998573339
#
# 39.7689150139, -86.1578930349
#
# 33.8647319724, -118.360905043
#
# 47.6446122746, -122.1685999
#
# 39.2862503078, -76.614669291
#
# 34.0489281, -111.0937311
#
# 40.440149171, -79.9962351025
#
# 34.1300022538, -118.129907002
#
# 40.7888742529, -74.1672690796
#
# 37.5426446892, -122.301848566
#
# 33.641619053, -117.74657161
#
# 33.8057742128, -118.155494097
#
# 40.8730178974, -73.89192718
#
# 41.487930321, -81.700104414
#
# 29.4249166324, -98.4936241079
#
# 26.1284068874, -80.1492550224
#
# 35.7707082023, -78.6380568513
#
# 38.6447924678, -90.2269969888
#
# 51.5027862709, -0.124192348031
#
# 44.9654072737, -93.1199160778
#
# 38.5815330878, -121.495651457
#
# 40.7028989625, -73.6043834588
#
# 38.9821456203, -77.3817539951
#
# 38.8672357258, -77.2625618097
#
# 34.1060735533, -117.985698571
#
# 40.7621728011, -111.896236723
#
# 39.130994872, -84.5019709031
#
# 37.542944669, -77.4685887934
#
# 36.164203998, -86.7814398082
#
# 49.2413662241, -123.112583746
#
# 35.2013516, -111.639249
#
# 40.0149856, -105.2705456
#
# 38.987164164, -77.0886833892
#
# 32.8796323865, -97.0113325719
#
# 41.0112104682, -73.7769705151
#
# 34.0565255959, -117.660168538
#
# 41.2539300416, -95.9991992855
#
# 40.4855061059, -74.4263852797
#
# 29.9646352166, -90.070561821
#
# 42.0640372782, -87.7847628614
#
# 41.8552617739, -87.8726234834
#
# 37.6930336787, -122.097844778
#
# 44.8842608722, -93.3273188278
#
# 40.7107181151, -74.3178496929
#
# 30.3326448916, -81.6543053277
#
# 43.0728378947, -89.3999034224
#
# 40.6410503464, -74.2324548571
#
# 33.864529491, -118.038643526
#
# 42.9011707163, -78.8748138298
#
# 38.9858973366, -94.6722020437
#
# 34.2101250795, -118.527490877
#
# 32.9953425188, -96.7094274462
#
# 26.0064465899, -80.2016235471
#
# 40.6099185881, -74.1194952089
#
# 34.0572469489, -84.3175723805
#
# 43.1622016389, -77.6110725847
#
# 33.9702384306, -84.5705031769
#
# 43.048204068, -76.1479162189
#
# 42.3307432623, -83.04239256
#
# 36.0768188842, -86.6515545725
#
# 34.0719085394, -117.830665411
#
# 42.95560472, -85.6800597948
#
# 28.6511401533, -81.3423552704
#
# -0.3012262, 36.5229641
#
# 35.1495343, -90.0489801
#
# -23.5489433, -46.6388182
#
# 42.4801821609, -83.1606514745
#
# 47.4715006132, -122.265766879
#
# 38.2534614149, -85.759421314
#
# 37.5566951924, -121.994125282
#
# 19.4306841132, -99.1421502904
#
# 39.1071371724, -77.1802406898
#
# 37.9350394777, -122.524048235
#
# 42.0683652179, -87.9788212552
#
# 39.9147039878, -75.0073163
#
# 35.7891041673, -78.80416964
#
# 41.7913181667, -88.1131736079
#
# 42.2710333311, -83.7266235292
#
# 41.0536001291, -73.5460492845
#
# 33.9846107041, -117.980240872
#
# 40.065524633, -74.3943064155
#
# 36.033669, -115.002364
#
# 36.778261, -119.4179324
#
# 32.726070496, -97.321011282
#
# 28.3825570729, -81.5378726694
#
# 42.2836792434, -85.5861645525
#
# 44.8607885333, -93.4976446167
#
# 39.0984450051, -76.6445019182
#
# 33.1837703797, -117.346478841
#
# 45.5057787602, -73.5587456929
#
# 42.5604248, -83.3621630037
#
# 40.0596232286, -75.337726381
#
# 27.7796632011, -82.6456410389
#
# 39.9785249111, -86.0537847111
#
# 35.4685426179, -97.51679604
#
# 41.5974263567, -93.7306631021
#
# 37.9125683567, -122.063602521
#
# 33.2362374707, -111.624031498
#
# 32.7843057374, -79.9205039857
#
# 42.9995338845, -88.0220370272
#
# 40.8322120141, -74.4475933268
#
# 42.3094060168, -83.4177085432
#
# 39.6187954391, -104.993854311
#
# 34.3819655525, -118.530235281
#
# 26.3417037642, -80.0890196842
#
# 38.9516029365, -92.3343964929
#
# 34.0005194485, -84.1608320515
#
# 32.9219988421, -97.1580578785
#
# 32.7522138015, -97.0846247877
#
# 42.0051205679, -88.1004780641
#
# 30.4416425602, -84.2858799458
#
# 35.9940329, -78.898619
#
# 40.7242880752, -73.3670046584
#
# 39.8407510885, -105.02437621
#
# 38.5300972316, -90.3810905759
#
# 35.9130061949, -79.0570751962
#
# -6.91310210127, 107.607742759
#
# 39.5298359115, -119.811452158
#
# 39.0820558595, -77.53459855
#
# 26.2657409881, -80.2396483762
#
# 1.35083660256, 103.820220413
#
# 41.1348402702, -73.3816689211
#
# 33.9335491191, -84.2871977559
#
# 45.0495091311, -93.4053718932
#
# 39.8331881413, -75.1200768556
#
# 35.0844909, -106.6511367
#
# 32.7937055632, -116.987878503
#
# 25.698997235, -80.2861423013
#
# 40.3147093714, -74.6643952571
#
# 40.2944328923, -74.0098947904
#
# 43.5870665973, -116.195863984
#
# 40.5858157527, -105.085143741
#
# 21.3055708649, -157.856817284
#
# 40.5244174118, -74.2998221078
#
# 31.7587198, -106.4869314
#
# 37.6846486592, -121.903596396
#
# 33.1434524447, -96.8451658526
#
# 42.7360893494, -84.5227457247
#
# 42.627718442, -83.1974769986
#
# 42.3428835641, -71.2773298359
#
# 38.8338816, -104.8213634
#
# 33.0182368826, -117.282993978
#
# 40.8074544588, -96.68141625
#
# 40.1818517091, -75.2712048227
#
# 37.09024, -95.712891
#
# 41.304259176, -72.929830438
#
# 36.8115821224, -76.2845886343
#
# 33.7888322478, -84.2675449896
#
# 48.857765547, 2.34579836515
#
# 41.6005448, -93.6091064
#
# 33.0581063, -112.0476423
#
# 40.1192978797, -74.0620610644
#
# 39.9652269917, -74.9265918917
#
# 39.7294319, -104.8319195
#
# 39.2245848094, -76.8390362698
#
# 42.4844284286, -83.433816346
#
# 41.0833891519, -81.5177294926
#
# 36.8529263, -75.977985
#
# 33.9556792286, -83.3815783429
#
# 41.0748389607, -74.0475514321
#
# 39.3830838302, -76.7606651837
#
# 33.1622098774, -96.6495485806
#
# 44.8869746148, -92.970317618
#
# 41.8224861377, -71.408106023
#
# 35.9634935639, -83.9171275098
#
# 33.1306953164, -117.124322526
#
# 47.3493912621, -122.268167345
#
# 41.6811683583, -86.2389442233
#
# 40.4163600875, -74.2362776167
#
# 40.3544492652, -74.1189553652
#
# 13.72643201, 100.501365816
#
# -6.31890613214, 106.807237975
#
# 44.7820870241, -93.1836724966
#
# 35.6800056224, 139.706056291
#
# 44.0517621053, -123.083347037
#
# 41.7933289655, -72.6914883879
#
# 34.8525673333, -82.3920335088
#
# 43.6586968, -70.2537349661
#
# 41.4657018646, -81.8463981271
#
# 39.9753519607, -105.093241427
#
# 36.0331164, -86.7827772
#
# 34.4219613643, -119.693467614
#
# 40.5958578048, -74.4882892738
#
# 37.566535, 126.9779692
#
# 33.4558074298, -117.646623777
#
# 42.5343249973, -82.9616993919
#
# 34.0540489, -117.199088542
#
# 32.9867017024, -96.9226844622
#
# 44.4797548926, -73.1944020833
#
# 41.8165778081, -72.5050628973
#
# 41.1727924846, -73.2171140192
#
# 40.9458023627, -74.1967118687
#
# 39.7644052137, -84.1916505314
#
# 34.1641826396, -118.826450394
#
# 34.0003015113, -81.0370314623
#
# 40.5859357914, -111.894914747
#
# 37.6922361, -97.3375448
#
# 32.793783692, -117.227353372
#
# 45.1157329079, -93.2501022158
#
# 42.777654864, -71.467243832
#
# 41.8023635667, -88.3169707476
#
# 30.4507462, -91.154551
#
# 27.9408382841, -82.7957045568
#
# 47.78685907, -122.191604392
#
# 43.5499749, -96.700327
#
# 42.2125671577, -87.9665051981
#
# 39.165325, -86.5263857
#
# 33.955129368, -117.397065084
#
# 47.987896502, -122.199018469
#
# 42.5192675346, -70.9137779154
#
# 40.1283597694, -74.9358712944
#
# 27.91356209, -82.251473484
#
# -7.26771537143, 112.741673265
#
# 42.241377474, -70.967408332
#
# 38.8223861979, -77.4201521396
#
# 36.0726282959, -79.7965943408
#
# 33.6528507386, -84.4438062068
#
# 26.7043585087, -80.0512912304
#
# 40.8642711621, -73.3756974328
#
# 38.7347945727, -121.24116757
#
# 36.1539816, -95.992775
#
# 13.7953476, 100.630875855
#
# -22.9035393, -43.2095869
#
# 41.7286045289, -87.7027141684
#
# 38.7340897122, -77.2070693327
#
# 33.4930992939, -86.7989126
#
# 32.062687937, -81.1015702087
#
# 28.537745135, -81.5584829675
#
# 28.2919557, -81.407571
#
# 27.6648274, -81.5157535
#
# 44.2601702822, -88.4138840378
#
# 42.936994714, -78.7507589512
#
# 41.5227277683, -90.5410787241
#
# 41.3530809571, -73.4518609
#
# 39.3637404636, -74.4241640295
#
# 38.8813958, -94.8191285
#
# 30.41275364, -87.2098405667
#
# 29.6516344, -82.3248262
#
# 55.7483495182, 37.6238504182
#
# 40.2219124867, -74.7935207978
#
# 47.2520261562, -122.438839087
#
# 42.2058190325, -71.193142695
#
# 41.262422925, -73.0458527375
#
# 36.7477272, -119.7723661
#
# 33.8875932689, -117.561823924
#
# 45.4265248149, -122.793915755
#
# 42.4363318222, -71.4439628667
#
# 40.1138411, -88.2367026143
#
# 38.9716689, -95.2352501
#
# 38.6089420205, -90.5568022705
#
# 34.0775016738, -84.0464900333
#
# 33.9714043703, -118.167855643
#
# 31.9685988, -99.9018131
#
# 26.4912159605, -80.0707980186
#
# 3.13880624167, 101.686777331
#
# 42.6211900549, -71.1217137627
#
# 41.079273, -85.1393513
#
# 33.604978652, -86.6369663411
#
# 30.4948140268, -97.6674049366
#
# 42.67808821, -73.7431676225
#
# 40.49620266, -88.99246486
#
# 40.1533505848, -75.1113381061
#
# 38.047248234, -122.285782504
#
# 36.973905175, -122.020079637
#
# 36.359582685, -94.179476005
#
# 33.3908801271, -112.197822695
#
# 52.5234051, 13.4113999
#
# 42.2521983324, -71.4456891297
#
# 41.5989457083, -87.7563460292
#
# 40.5203891268, -74.6506926878
#
# 39.7483473914, -75.5456546086
#
# 39.4349843067, -76.6187259933
#
# 35.9250637, -86.8688899
#
# 51.045, -114.0572222
#
# 45.4010912895, -75.7051333684
#
# 42.5299696017, -71.201431239
#
# 41.2108497625, -73.942985825
#
# 40.2735251, -76.8905458658
#
# 38.9826975286, -76.5014846786
#
# 28.0382682737, -81.9478057947
#
# 26.1388437868, -80.3343468368
#
# 47.8052920108, -122.344463373
#
# 42.2527287317, -71.7903823854
#
# 40.1008460571, -83.1152923686
#
# 39.0982969771, -76.9039521686
#
# 34.7514357595, -92.2848499243
#
# 44.9099903842, -93.6269883921
#
# 42.9924137514, -71.4658623
#
# 41.7113985818, -73.9200892879
#
# 40.7491647389, -73.0824334472
#
# 39.7335787, -86.3801812814
#
# 29.9867312917, -90.2039336556
#
# 28.0654871667, -80.5993049111
#
# -0.789275, 113.921327
#
# 47.5317897257, -122.028410329
#
# 42.3325796167, -88.2475629083
#
# 40.9604889971, -72.2086191457
#
# 40.1304704629, -82.9411098857
#
# 43.0259703838, -88.2313161676
#
# 42.6526391382, -83.0084165088
#
# 42.4241755111, -82.9096115593
#
# 42.0166667, -94.3766667
#
# 41.5031631371, -73.0825761857
#
# 39.9013274174, -75.3635647087
#
# 39.4130433118, -77.4112680382
#
# 39.3307662697, -74.5783040273
#
# 38.3047222, -122.2988889
#
# 34.7303688, -86.5861037
#
# 34.0987712886, -84.5176581057
#
# 33.5095943, -117.165718494
#
# 41.264587163, -73.8161541852
#
# 38.4367590703, -122.728322351
#
# 35.5183780762, -80.8314881524
#
# 34.2257255, -77.9447102
#
# 33.3703197, -112.5837766
#
# 29.2111177303, -81.0235402152
#
# 27.8005828, -97.396381
#
# 25.2644444, 55.3116667
#
# -8.66968122581, 115.213551903
#
# 43.2106060486, -87.9625810838
#
# 42.1024738476, -71.4345807857
#
# 42.0998897108, -75.9427548432
#
# 40.6156626906, -75.36652545
#
# 39.5565705999, -104.82665568
#
# 35.0456297, -85.3096801
#
# 34.0986573656, -117.355809122
#
# 32.4619138719, -84.9889333906
#
# 20.6762822937, -103.347315313
#
# 3.5848877375, 98.67732915
#
# 52.3729639903, 4.89231722258
#
# 48.7595529, -122.4882249
#
# 46.7802946548, -92.1008330452
#
# 44.648553592, -93.230819564
#
# 41.4868664882, -81.5338317294
#
# 40.8942060929, -73.0819252107
#
# 40.7935000452, -77.857595071
#
# 40.2946147786, -74.31064935
#
# 40.1631208129, -105.106372132
#
# 39.9691705541, -75.6024447027
#
# 38.0317136, -84.4951359
#
# 34.2659, -119.258366
#
# 26.6440687097, -81.8733119742
#
# 14.5944461258, 121.015826494
#
# 42.2894592607, -71.593657325
#
# 42.2582939187, -83.1854810406
#
# 39.9625984, -76.727745
#
# 39.9490233147, -74.1378186294
#
# 39.0558235, -95.6890185
#
# 38.609205076, -121.303772536
#
# 33.9417363062, -83.9827021562
#
# 33.5685780815, -84.3197174259
#
# 39.0201078219, -84.6213113
#
# 38.9825700453, -76.8793682641
#
# 38.0293059, -78.4766781
#
# 36.1944697813, -94.1290051
#
# 34.0050079, -118.8100893
#
# 33.8333716, -111.9507042
#
# 30.6442647897, -96.3489137586
#
# 28.3297016724, -80.6728876966
#
# 27.3364347, -82.5306527
#
# 21.3778098414, -158.003045134
#
# 46.729553, -94.6858998
#
# 45.6387281, -122.6614861
#
# 42.8932504214, -87.863381425
#
# 42.4439614, -76.5018807
#
# 42.2069914792, -88.2967505542
#
# 42.058436, -70.1786374
#
# 41.615915, -88.204069
#
# 40.5116828821, -80.1961084107
#
# 40.4124087731, -79.8485564615
#
# 40.3385564621, -74.5296209207
#
# 39.3565774429, -84.4973694143
#
# 36.1987264, -86.5878606357
#
# 35.8456213, -86.39027
#
# 33.5778631, -101.8551665
#
# 32.7253248, -114.624397
#
# 25.8456722643, -80.3188905964
#
# -33.8606304286, 151.204775929
#
# 61.2180556, -149.9002778
#
# 46.8768199222, -96.7872943778
#
# 45.5223169, -122.411026963
#
# 43.4515758148, -80.4999384815
#
# 42.7261309, -87.7828523
#
# 41.5364839286, -87.4927188821
#
# 41.3525524462, -72.1094852308
#
# 40.0289868111, -76.3163172889
#
# 37.6594499444, -77.5133409741
#
# 36.0998596, -80.244216
#
# 36.0572773889, -94.1658606556
#
# 31.230393, 121.473704
#
# -33.4257406407, -70.5707398593
#
# 47.6587802, -117.4260466
#
# 42.1292241, -80.085059
#
# 41.9981228231, -91.6697868692
#
# 41.2033216, -77.1945247
#
# 40.69191548, -89.591508764
#
# 40.2797455167, -111.684785675
#
# 40.1210773538, -75.4908632731
#
# 39.6837226, -75.7496572
#
# 37.2136113231, -93.2966431038
#
# 33.1967668414, -97.1163339103
#
# 32.9398771115, -96.5904837115
#
# 29.6195397923, -95.6319761385
#
# 18.4322590926, -66.1157937852
#
# -7.79371125185, 110.365283344
#
# -34.6119959577, -58.3718653577
#
# 43.074149144, -70.772261672
#
# 42.0540019375, -88.2786205062
#
# 42.0591235458, -71.1958612583
#
# 41.6914588842, -71.4359778
#
# 41.6118798478, -87.9051756217
#
# 40.6294525, -75.49198334
#
# 40.29423375, -75.1334047917
#
# 34.6100243, -112.315721
#
# 30.2870405808, -81.3966798385
#
# 45.5254108, -122.976122233
#
# 44.0247062, -88.5426136
#
# 41.5898431167, -83.6716027833
#
# 41.3653952409, -81.3907805455
#
# 40.661142155, -74.6007632
#
# 39.755543, -105.2210997
#
# 38.7809192917, -90.534779225
#
# 37.9512591238, -121.682307362
#
# 36.6036303923, -121.885828488
#
# 30.0080668292, -95.2366504625
#
# 28.6980343906, -81.2124398031
#
# 45.4102240625, -122.626528121
#
# 43.5521160609, -79.6279655043
#
# 43.203612335, -70.87233645
#
# 41.6813781391, -91.5701626304
#
# 41.1725429095, -81.3999909714
#
# 41.00527, 28.97696
#
# 40.4206875913, -86.8895384652
#
# 39.5872222, -78.8425
#
# 39.3722121, -104.8560902
#
# 39.3460977304, -76.4911708609
#
# 38.7289405739, -75.0896012696
#
# 38.5966977348, -122.857686835
#
# 32.0595018783, 34.788656713
#
# -37.8090540565, 144.966681387
#
# 47.0389673727, -122.904727245
#
# 44.5078962364, -88.0276415045
#
# 44.0216306, -92.4698992
#
# 43.7844397, -88.7878678
#
# 43.2049408762, -88.1136758143
#
# 43.1373693591, -77.4511946136
#
# 41.3616922783, -81.591273113
#
# 39.7452229333, -74.9717190958
#
# 37.6370896727, -120.995097818
#
# 36.9989217591, -76.3916683091
#
# 35.6005903136, -82.5504359409
#
# 35.4087517, -80.579511
#
# 34.4235565636, -119.845820482
#
# 34.2694474, -118.781482
#
# 33.8097573552, -84.6539735448
#
# 25.673211, -100.309201
#
# 42.8197807905, -73.9378692667
#
# 42.3332032613, -87.8729844065
#
# 39.6417680476, -106.562543733
#
# 37.6818745, -121.7680088
#
# 36.6777372, -121.6555013
#
# 35.2219971, -101.8312969
#
# 34.5400242, -112.4685025
#
# 34.483901, -114.3224548
#
# 33.8302961, -116.5452921
#
# 32.8795022, -111.7573521
#
# -6.18396622381, 106.624447167
#
# 44.9428975, -123.0350963
#
# 42.63824706, -71.379054085
#
# 42.2740068529, -89.0918873706
#
# 41.6619105, -83.54837848
#
# 40.63109402, -89.40460156
#
# 39.6671647053, -84.1263549
#
# 38.545003715, -121.738197205
#
# 35.2827524, -120.6596156
#
# 34.9530337, -120.4357191
#
# 34.2073196, -84.1401926
#
# 53.3428873263, -6.26930292105
#
# 42.1823240889, -88.1198927556
#
# 41.4477306737, -74.0284128789
#
# 41.3609249944, -71.9286042278
#
# 41.3272870238, -81.8451482238
#
# 40.8729898739, -74.571171087
#
# 38.4087993, -121.3716178
#
# 38.0151062238, -121.86072469
#
# 37.4315734, -78.6568942
#
# 35.6528323, -97.4780954
#
# 34.8697395, -111.7609896
#
# 33.7075805737, -116.237126942
#
# 32.216316, -80.752608
#
# 29.9382717474, -93.9207204737
#
# 26.2026892053, -98.2316034
#
# 26.1420358, -81.7948103
#
# 22.396428, 114.109497
#
# 48.4330612, -123.361904533
#
# 47.6057968167, -122.669803617
#
# 42.3516742722, -72.57957465
#
# 41.8780025, -93.097702
#
# 41.1484728778, -111.992544811
#
# 40.6460622, -111.4979729
#
# 40.4174554944, -3.7009102
#
# 40.3878639499, -75.951441732
#
# 38.4565458444, -122.418960178
#
# 37.9745863333, -87.5566949556
#
# 35.3732921, -119.0187125
#
# 30.6943566, -88.0430541
#
# 30.5174659167, -97.8257521
#
# 29.7857853, -95.8243956
#
# 21.158964, -86.845937
#
# -6.24751230476, 107.128189467
#
# 55.6868261765, 12.5899425529
#
# 53.543564, -113.490452
#
# 44.7630567, -85.6206317
#
# 42.8806425, -71.3272856
#
# 41.4460157647, -75.6680767176
#
# 41.1399814, -104.8202462
#
# 37.9577016, -121.2907796
#
# 37.1305012, -121.6543901
#
# 34.6867846, -118.1541632
#
# 33.4758669765, -82.0070491294
#
# 32.6098566, -85.4807825
#
# 30.0799405, -95.4171601
#
# -33.0504619, -71.6164515
#
# 60.1699538875, 24.9377301188
#
# 50.1115118, 8.6805059
#
# 44.0581728, -121.3153096
#
# 43.685271, -79.759924
#
# 43.6808560625, -72.2879520875
#
# 43.0961709, -88.40263155
#
# 42.7653543125, -78.7826006875
#
# 42.115474425, -79.2863677125
#
# 42.0791339318, -70.9757757864
#
# 41.6308593923, -88.0477856231
#
# 41.6338200941, -72.6417292059
#
# 41.2674496421, -75.8811320895
#
# 38.0411820688, -122.150053263
#
# 37.2707022, -76.7074571
#
# 37.2046429, -80.4126892
#
# 36.8252277, -119.7029194
#
# 35.5280783, -108.7425843
#
# 34.935238425, -82.234904475
#
# 32.3199396, -106.7636538
#
# 9.95896848125, -84.1056328563
#
# 30.4146644294, -86.5335282118
#
# 35.1378677111, -89.7851773389
#
# 41.4678069625, -70.5840377312
#
# 32.5883647312, -96.8752963812
#
# 41.5399274105, -73.4115528263
#
# 41.1765187115, -73.72200985
#
# 41.6604506522, -88.3841930174
#
# 39.1887019095, -77.258513619
#
# 38.6950244211, -76.9943945158
#
# -45.0311622, 168.6626435

# %% [markdown]
# Define function, which calculates distances between points assigned in geographic coordinate system.

# %%
def distance(lat_office, long_office, lat_cl, long_cl):
    return np.arccos(np.sin(lat_office) * np.sin(lat_cl) + np.cos(lat_office) * np.cos(lat_cl) * np.cos(long_office - long_cl))

# %% [markdown]
# Lets calculate distances between each cluster centre and the closest Carnival Cruise Line office.

# %%
min_distances = []
offices_coord = [(33.751277, -118.188740),
                 (25.867736, -80.324116),
                 (51.503016, -0.075479),
                 (52.378894, 4.885084),
                 (39.366487, 117.036146),
                 (-33.868457, 151.205134)]

for coord in centers_of_bigger_clusters:
    distances = [] #distances between current cluster center and each of 6 offices
    for office_coord in offices_coord:
        distances.append(distance(office_coord[0], office_coord[1], coord[0], coord[1]))
    min_distances.append(min(distances))

# %% [markdown]
# We got a final solution of our task below. It's first 20 the closest to offices clusters centres.

# %%
min_distances = np.array(min_distances)
coord_to_place_banners = []
for i in min_distances.argsort()[:20]:
    coord_to_place_banners.append(centers_of_bigger_clusters[i])

# %% [markdown]
# https://www.mapcustomizer.com/map/clusters_centres_to_place_banners

# %%
for coord in coord_to_place_banners:
    print format(coord[0]) + ', ' + format(coord[1]) + '\n'
# Out:
# 52.3729639903, 4.89231722258
#
# -33.8606304286, 151.204775929
#
# 51.5027862709, -0.124192348031
#
# 25.8456722643, -80.3188905964
#
# 39.3565774429, -84.4973694143
#
# 41.5364839286, -87.4927188821
#
# 32.8795022, -111.7573521
#
# 21.158964, -86.845937
#
# 13.7953476, 100.630875855
#
# 33.8057742128, -118.155494097
#
# 39.4130433118, -77.4112680382
#
# 33.5778631, -101.8551665
#
# 39.165325, -86.5263857
#
# 33.1434524447, -96.8451658526
#
# 39.5872222, -78.8425
#
# 13.72643201, 100.501365816
#
# 33.1622098774, -96.6495485806
#
# 36.973905175, -122.020079637
#
# 26.6440687097, -81.8733119742
#
# 45.6387281, -122.6614861
